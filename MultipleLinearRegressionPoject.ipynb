# %%
# %pip install pandas numpy matplotlib seaborn statsmodels scipy
# Out:
# Requirement already satisfied: pandas in c:\Users\OMG\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy in c:\Users\OMG\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.4.6)
# Requirement already satisfied: matplotlib in c:\Users\OMG\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.11.0)
# Requirement already satisfied: seaborn in c:\Users\OMG\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.13.2)
# Requirement already satisfied: statsmodels in c:\Users\OMG\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.14.6)
# Requirement already satisfied: scipy in c:\Users\OMG\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.17.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\OMG\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\OMG\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\OMG\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\OMG\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\OMG\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\OMG\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\OMG\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in c:\Users\OMG\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\OMG\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\Users\OMG\AppData\Local\Programs\Python\Python314\Lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: six>=1.5 in C:\Users\OMG\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy.stats import shapiro

# %%
df = pd.read_csv('C:marketing_sales_data.csv')
df.head()
print(df.info())
print(df.shape)
print(df.describe())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   TV            572 non-null    str
#  1   Radio         572 non-null    float64
#  2   Social Media  572 non-null    float64
#  3   Influencer    572 non-null    str
#  4   Sales         572 non-null    float64
# dtypes: float64(3), str(2)
# memory usage: 22.5 KB
# None
# (572, 5)
#             Radio  Social Media       Sales
# count  572.000000    572.000000  572.000000
# mean    17.520616      3.333803  189.296908
# std      9.290933      2.238378   89.871581
# min      0.109106      0.000031   33.509810
# 25%     10.699556      1.585549  118.718722
# 50%     17.149517      3.150111  184.005362
# 75%     24.606396      4.730408  264.500118
# max     42.271579     11.403625  357.788195

# %%
sns.pairplot(df)
plt.show()

# %%
priority_mapping = {'Low': 1, 'Medium': 2, 'High': 3}
df['TV'] = df['TV'].map(priority_mapping)

# %%
correlation_matrix = df.corr(numeric_only=True)
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm') 
plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['TV', 'Radio', 'Social Media', 'Influencer', 'Sales']

# %%
x = df[['TV', 'Radio', 'Social Media']]
y = df['Sales']

# %%
x_const = sm.add_constant(x)

vif = pd.DataFrame()
vif['variable'] = x_const.columns
vif['VIF'] = [variance_inflation_factor(x_const.values, i) for i in range(x_const.shape[1])]
print(vif)
# Out:
#        variable       VIF
# 0         const  7.040920
# 1            TV  2.820621
# 2         Radio  3.451590
# 3  Social Media  1.658144

# %%
model = sm.OLS(y, x_const).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.904
# Model:                            OLS   Adj. R-squared:                  0.903
# Method:                 Least Squares   F-statistic:                     1781.
# Date:                Tue, 23 Jun 2026   Prob (F-statistic):          2.10e-288
# Time:                        14:42:37   Log-Likelihood:                -2714.2
# No. Observations:                 572   AIC:                             5436.
# Df Residuals:                     568   BIC:                             5454.
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -12.2889      3.099     -3.966      0.000     -18.375      -6.202
# TV              77.3227      2.456     31.486      0.000      72.499      82.146
# Radio            2.9792      0.234     12.746      0.000       2.520       3.438
# Social Media    -0.1577      0.672     -0.235      0.815      -1.478       1.163
# ==============================================================================
# Omnibus:                       60.101   Durbin-Watson:                   1.874
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               17.942
# Skew:                           0.050   Prob(JB):                     0.000127
# Kurtosis:                       2.138   Cond. No.                         61.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
predictions = model.predict(x_const)
print(predictions.head())
# Out:
# 0     75.153085
# 1     87.737430
# 2    280.109361
# 3    201.833451
# 4    312.754065
# dtype: float64

# %%
residuals = model.resid
print(residuals.head())
# Out:
# 0   -19.891801
# 1   -20.162527
# 2    -7.859253
# 3    -6.731275
# 4   -38.793688
# dtype: float64

# %%
plt.figure(figsize=(7, 5))
sns.scatterplot(
    x= model.fittedvalues,
    y= residuals,
)
plt.axhline(y=0, linestyle='--')
plt.xlabel('fitted values')
plt.ylabel('residuals')
plt.show()

# %%
sns.histplot(residuals, kde=True)
plt.show()

# %%
sm.qqplot(residuals, line='45')
plt.show()

# %%
stat, p = shapiro(residuals)
print("Statistic:", stat)
print("p-value:", p)
# Out:
# Statistic: 0.9833342620365273
# p-value: 4.0517384562709585e-06

# %% [markdown]
# <h1>Business Recommendation</h1>
#
# <p>You can include this in your notebook:</p>
#
# <h2>Marketing Budget Recommendation</h2>
#
# <p>The multiple regression analysis shows that:</p>
#
# <ul>
#   <li>TV advertising has a positive and statistically significant impact on sales.</li>
#   <li>Radio advertising also contributes significantly to increased sales and exhibits a stronger marginal effect than TV.</li>
#   <li>Social Media spending does not significantly affect sales after controlling for TV and Radio expenditure.</li>
# </ul>
